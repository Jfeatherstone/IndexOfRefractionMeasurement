# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['font.size'] = 12

from tinkerforge.ip_connection import IPConnection
from tinkerforge.bricklet_humidity import BrickletHumidity
from tinkerforge.bricklet_temperature import BrickletTemperature

from IPython.display import clear_output
import time
import datetime

# %%
HOST = 'localhost'
PORT = 4223

HUMIDITY_UID = 'keg'
TEMP_UID = '6Jf'

# %%
ipcon = IPConnection()

humiditySensor = BrickletHumidity(HUMIDITY_UID, ipcon)
temperatureSensor = BrickletTemperature(TEMP_UID, ipcon)

ipcon.connect(HOST, PORT)

def millisTime():
    return int((datetime.datetime.utcnow() - datetime.datetime(1970, 1, 1)).total_seconds() * 1000)

# %%
temperatureArr = []
humidityArr = []
timeArr = []

start = millisTime()

while True:
    timeArr.append((millisTime() - start)/1000)

    temperatureArr.append(temperatureSensor.get_temperature()/100)
    humidityArr.append(humiditySensor.get_humidity()/10)
    
    clear_output(wait=True)
    
    fig, ax = plt.subplots(1, 2, figsize=(12,4))
    
    ax[0].plot(timeArr, temperatureArr)
    ax[0].set_ylabel('Temperature [C]')
    ax[0].set_xlabel('Time [s]')
    
    ax[1].plot(timeArr, humidityArr)
    ax[1].set_ylabel('Humidity [%]')
    ax[1].set_xlabel('Time [s]')

    fig.tight_layout()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-0b0f912fc9ae> in <module>
#      24
#      25     fig.tight_layout()
# ---> 26     plt.show()
#
# C:\Apps\WinPython\python-3.8.3.amd64\lib\site-packages\matplotlib\pyplot.py in show(*args, **kw)
#     270     """
#     271     global _show
# --> 272     return _show(*args, **kw)
#     273
#     274
#
# C:\Apps\WinPython\python-3.8.3.amd64\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# C:\Apps\WinPython\python-3.8.3.amd64\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# C:\Apps\WinPython\python-3.8.3.amd64\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-9> in __call__(self, obj)
#
# C:\Apps\WinPython\python-3.8.3.amd64\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# C:\Apps\WinPython\python-3.8.3.amd64\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# C:\Apps\WinPython\python-3.8.3.amd64\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# C:\Apps\WinPython\python-3.8.3.amd64\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# C:\Apps\WinPython\python-3.8.3.amd64\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2079                     self.figure.draw(renderer)
#    2080                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
# -> 2081                     bbox_inches = self.figure.get_tightbbox(renderer,
#    2082                             bbox_extra_artists=bbox_artists)
#    2083                     pad = kwargs.pop("pad_inches", None)
#
# C:\Apps\WinPython\python-3.8.3.amd64\lib\site-packages\matplotlib\figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    2383
#    2384         for a in artists:
# -> 2385             bbox = a.get_tightbbox(renderer)
#    2386             if bbox is not None and (bbox.width != 0 or bbox.height != 0):
#    2387                 bb.append(bbox)
#
# C:\Apps\WinPython\python-3.8.3.amd64\lib\site-packages\matplotlib\axes\_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists)
#    4315
#    4316         if self.axison:
# -> 4317             bb_xaxis = self.xaxis.get_tightbbox(renderer)
#    4318             if bb_xaxis:
#    4319                 bb.append(bb_xaxis)
#
# C:\Apps\WinPython\python-3.8.3.amd64\lib\site-packages\matplotlib\axis.py in get_tightbbox(self, renderer)
#    1184             return
#    1185
# -> 1186         ticks_to_draw = self._update_ticks()
#    1187
#    1188         self._update_label_position(renderer)
#
# C:\Apps\WinPython\python-3.8.3.amd64\lib\site-packages\matplotlib\axis.py in _update_ticks(self)
#    1109             tick.set_label1(label)
#    1110             tick.set_label2(label)
# -> 1111         minor_locs = self.get_minorticklocs()
#    1112         minor_labels = self.minor.formatter.format_ticks(minor_locs)
#    1113         minor_ticks = self.get_minor_ticks(len(minor_locs))
#
# C:\Apps\WinPython\python-3.8.3.amd64\lib\site-packages\matplotlib\axis.py in get_minorticklocs(self)
#    1351         """Get the array of minor tick locations in data coordinates."""
#    1352         # Remove minor ticks duplicating major ticks.
# -> 1353         major_locs = self.major.locator()
#    1354         minor_locs = self.minor.locator()
#    1355         transform = self._scale.get_transform()
#
# C:\Apps\WinPython\python-3.8.3.amd64\lib\site-packages\matplotlib\ticker.py in __call__(self)
#    2232     def __call__(self):
#    2233         vmin, vmax = self.axis.get_view_interval()
# -> 2234         return self.tick_values(vmin, vmax)
#    2235
#    2236     def tick_values(self, vmin, vmax):
#
# C:\Apps\WinPython\python-3.8.3.amd64\lib\site-packages\matplotlib\ticker.py in tick_values(self, vmin, vmax)
#    2240         vmin, vmax = mtransforms.nonsingular(
#    2241             vmin, vmax, expander=1e-13, tiny=1e-14)
# -> 2242         locs = self._raw_ticks(vmin, vmax)
#    2243
#    2244         prune = self._prune
#
# C:\Apps\WinPython\python-3.8.3.amd64\lib\site-packages\matplotlib\ticker.py in _raw_ticks(self, vmin, vmax)
#    2179         if self._nbins == 'auto':
#    2180             if self.axis is not None:
# -> 2181                 nbins = np.clip(self.axis.get_tick_space(),
#    2182                                 max(1, self._min_n_ticks - 1), 9)
#    2183             else:
#
# C:\Apps\WinPython\python-3.8.3.amd64\lib\site-packages\matplotlib\axis.py in get_tick_space(self)
#    2188         ends = self.axes.transAxes.transform([[0, 0], [1, 0]])
#    2189         length = ((ends[1][0] - ends[0][0]) / self.axes.figure.dpi) * 72
# -> 2190         tick = self._get_tick(True)
#    2191         # There is a heuristic here that the aspect ratio of tick text
#    2192         # is no more than 3:1
#
# C:\Apps\WinPython\python-3.8.3.amd64\lib\site-packages\matplotlib\axis.py in _get_tick(self, major)
#    1941         else:
#    1942             tick_kw = self._minor_tick_kw
# -> 1943         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1944
#    1945     def _get_label(self):
#
# C:\Apps\WinPython\python-3.8.3.amd64\lib\site-packages\matplotlib\axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     156
#     157         self.tick1line = self._get_tick1line()
# --> 158         self.tick2line = self._get_tick2line()
#     159         self.gridline = self._get_gridline()
#     160         self.label1 = self._get_text1()
#
# C:\Apps\WinPython\python-3.8.3.amd64\lib\site-packages\matplotlib\axis.py in _get_tick2line(self)
#     471         'Get the default line2D instance'
#     472         # x in data coords, y in axes coords
# --> 473         l = mlines.Line2D(xdata=(0,), ydata=(1,),
#     474                           color=self._color,
#     475                           linestyle='None',
#
# C:\Apps\WinPython\python-3.8.3.amd64\lib\site-packages\matplotlib\lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     376         self._color = None
#     377         self.set_color(color)
# --> 378         self._marker = MarkerStyle(marker, fillstyle)
#     379
#     380         self._markevery = None
#
# C:\Apps\WinPython\python-3.8.3.amd64\lib\site-packages\matplotlib\markers.py in __init__(self, marker, fillstyle)
#     223         self._marker_function = None
#     224         self.set_fillstyle(fillstyle)
# --> 225         self.set_marker(marker)
#     226
#     227     def _recache(self):
#
# C:\Apps\WinPython\python-3.8.3.amd64\lib\site-packages\matplotlib\markers.py in set_marker(self, marker)
#     294
#     295         self._marker = marker
# --> 296         self._recache()
#     297
#     298     def get_path(self):
#
# C:\Apps\WinPython\python-3.8.3.amd64\lib\site-packages\matplotlib\markers.py in _recache(self)
#     236         self._capstyle = 'butt'
#     237         self._filled = True
# --> 238         self._marker_function()
#     239
#     240     def __bool__(self):
#
# C:\Apps\WinPython\python-3.8.3.amd64\lib\site-packages\matplotlib\markers.py in _set_tickup(self)
#     726
#     727     def _set_tickup(self):
# --> 728         self._transform = Affine2D().scale(1.0, 1.0)
#     729         self._snap_threshold = 1.0
#     730         self._filled = False
#
# C:\Apps\WinPython\python-3.8.3.amd64\lib\site-packages\matplotlib\transforms.py in __init__(self, matrix, **kwargs)
#    1842         if matrix is None:
#    1843             # A bit faster than np.identity(3).
# -> 1844             matrix = IdentityTransform._mtx.copy()
#    1845         self._mtx = matrix
#    1846         self._invalid = 0
#
# KeyboardInterrupt:
